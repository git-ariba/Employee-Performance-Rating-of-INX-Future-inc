# %% [markdown]
# Name: **Ariba Cindy Cota**
#
#
# Module :**Certified Data Scientist - Project**.     Project Code: **10281**
#
# REP Name: **DataMites™ Solutions Pvt Ltd**.          Registered Trainer: **Ashok Kumar A**

# %% [markdown]
# # Table of Content
#
# ### 1.Business Case
# -the case
#
# ### 2. Data Summary
# - Attributes list
# - Basic libraries imported
# - Basic Data Checks
#
# ### 3. Exploratory Data Analysis Findings
# - Univatiate Analysis
# - Bivariate Analysis  (Task 1)
# - Multivariate Analysis
#
# ### 4. Data Pre Processing
# - Standard Scale to scale data
# - Null/duplicate values
# - Encoding data -Lable Encoder
# - Outliers- Box Plots
#
# ### 5. Feature Engineering
# - Feature Transformation: Standardization (StandardScalar)
# - Feature Selection: Chi sq   (Task 2)
# - Feature Extraction : PCA tried and tested but underperformed.
#
# ### 6. Models and Model evaluation
# - SMOTE for Data Balancing
# - Support Vector Classifier(Hyperparameter tuning was done)
# - Logistic Regression
# - Decision Tree Classifier(Hyperparameter tuning was done)
# - Random Forest Classifier(Hyperparameter tuning was done)
# - K-Nearest Neighbour
# - X-Gboost Classifier (Hyperparameter tuning was done)
# - Naive Bayes
# - Deep Learning model : Artificial Neural Network (Hyperparameter tuning was done)
# - Task 3 & 4
#
#
# ________________________________________________________________

# %% [markdown]
# # INX Future Inc. - Employee Performance Report Analyses

# %% [markdown]
# # Business Case
#
# **Business presence**
# \
# INX Future Inc. also referred to as INX, has over 15 years of global business presence as a Data Analytics and Automation solutions provider. In it's domain INX has been one of the foremost brands during it tenure, additionally it has been consistently rated as top 20 best employers for the past 5 years and it's  Human resource policies are considered as employee friendly and widely perceived as the best practices in the industry.
#
#
# **Case illustration**
# \
# It has been observed by the management that in Recent years;
# - A. It's employee performance indexes show signs of decline, and this is a concern to the top-level management.
# - B. There has been a noticeable increase in service delivery and
# - C. Client satisfaction levels have come down by 8 percentage points.
#
# The current CEO, Mr. Brain, is aware of the issues and is concerned because any measures taken against the non-performing
# employees would affect the morale of all the employees in general and this inturn could reduce the employee performance even further; additionally, the company is perceived to have a good reputation for being the best employer, which inturn attracts it's  best talent.
#
# Being mindful, Mr. Brain decided to initiate a data science project. this project would aim to;
# - **Analyze the current employee data**
# - **Find the root underlying causes of this performance issues**.
# \
# Mr. Brain, a data scientist himself, expects that the findings of the project would aid in making corrective choices including, **providing clear indicators of non performing employees**, so that any penalization of non-performing employees, if need be, may have minimal impact on the morale of other employees.

# %% [markdown]
# ### **Tasks / Required Insights**
# - Task 1. To project Department wise performances
# - Task 2. To list the Top 3 Important Factors effecting employee performance
# - Task 3. To prepare a trained model which can predict the employee performance based on factors as inputs. This will be used to hire employees
# - Task 4. To provide Recommendations to improve the employee performance based on insights from analysis
#
#
# note:
#
# Task 1 covered under **Exploratory Data Analysis** / Bivariate Analysis
#
# Task 2 covered under **Feature Engineering**
#
# Task 3 covered towards the end of **Model Evaluation**
#
# Task 4 covered under **Recommendations**

# %% [markdown]
# ### **Case Type**
#
# #### Multi-Class Classification: **To predict the Employee Performance Rating based on Independent variables**
#
#
# Ratings/Target variables are marked as follows:
# - 1- *Low*
# - 2- *Good*
# - 3- *Excellent*
# - 4- *Outstanding*

# %% [markdown]
# ### Attributes Summary

# %% [markdown]
# ##### Independent Attributes :  How an independent variables may or may not impact the target variable
#
# 1. **EmpNumber**: Employee number is a unique key given to each employee, each key is distinct from one another hense will not mean productive in our model creation (this column will be dropped)
#
#
# 2. **Age**: Age of employees is a continuous variable, and would determine the productivity against changing age.
#
#
# 3. **Gender**: This is a descrete feature that would help determine the output with respect the gender.
#
#
# 4. **EducationBackground**: The Educational Background
#
#
# 5. **MaritalStatus**: This attribute would help understand how much time/concentration/determination employees can give based on their maritial status i.e. married, single or divorced
#
#
# 6. **EmpDepartment**: The Depertment wise classification would provide data of output per department and help understanding the least or most productive department
#
#
# 7. **EmpJobRole**: The Job Role would help determine the employees departmental position in the company, for example, Sales Executive, sales representative Data Scientist, Developer, etc.
#
#
# 8. **BusinessTravelFrequency**:This Attribute would mean moving from one place to another to communicate vital information of the company. and is typically assigned to experianced/trusted employees. this is a categorical variable.
#
#
# 9. **DistanceFromHome**: This Attribute is a continuous variable (assuming it is in KiloMeters/ Km) that would explains the distance an employee would have to commute to be at work, it is known that travelling longer distances is related to exhaution.
#
#
# 10. **EmpEducationLevel**:The Qualification level of an employee would play a vital role for them in understanding their respective stream in terms of knowledge and expertise, which could aid in understanding their quality of outputs. the levels read as follows; **1-Below College, 2-College, 3-Bachelor, 4-Master, 5-Doctor**.
#
#
# 11. **EmpEnvironmentSatisfaction**: this attribute will aid in understanding the the level of setisfaction of an employee in the work environment. the levels read as follows ;  **1-Low, 2-Medium, 3-High, 4-Very High**. the satisfaction levels range from 1 being the least satisfied to 4 being highly satisfied.
#
#
# 12. **EmpHourlyRate**:An employee hourly rate is an amount of money/rate an employee is paid for each hour of work they perform. The rate can range from 30 to 100 (assuming Indian Rupees)
#
#
# 13. **EmpJobInvolvement**:An Employees involvement at the job refers to the extent to which they are intentionally invested, committed and motivated at their work. It reflects the level of interest, dedication an employee has for their job, the differet levels of involvement are as follows; **1-Low, 2-Medium, 3-High, 4-Very High** (1 being the least involved and 4 being the most involved employee)
#
#
# 14. **EmpJobLevel**: Employee job levels 1, 2, 3, and 4 are often used in companies to categorize various roles and responsibilities of their employees. (The specific job levels/designations can vary from one organization to another) assuming, 1 being the ground level and 4 being the top most designation.
#
#
# 15. **EmpJobSatisfaction**:this attribute will help understand the the level of setisfaction of an employee towards their job role and the work that is involved in that role. the levels read as follows ;  **1-Low, 2-Medium, 3-High, 4-Very High**. the satisfaction levels range from 1 being the least satisfied towards the job role to 4 being highly satisfied in their role.
#
#
# 16. **NumCompaniesWorked**:the number of companies an employee has worked for could determine positive aspects such as experiance and knowledge. At the same time can explain the employees stability in one organization, if the number is low it could mean higher stability and dedication to one company, if the number of copmanies worked at is too high it can also mean their instability and low interest in the role they are assigned to or the company they working at. the number there **ranges from 0 to 9**
#
#
# 17. **OverTime**: This is a Categorical attribute that classifies whether an employee has worked over time or not **(Yes/No)**, it could mean having an over load or also extra incentives for extra working hours.
#
#
# 18. **EmpLastSalaryHikePercent**: The range of the last salary hike is 12% to 25%, the last salary hike determines that the employee has been putting in the effort and is dedicated to their role, the employees feel recognized this motivates the employee to keep up their dedicated work, it also helps the Employer to retain and motivate their workforce. this metric is valuable for both employer and employees.
#
#
# 19. **EmpRelationshipSatisfaction**: the employee relationship satisfaction parameter ranges from 1 to 4; **1 Indicating Low, 2-Medium, 3-High, 4-Very High employee relationship satisfaction**. A good Employee relationship could boost performance.
#
#
# 20. **TotalWorkExperienceInYears**:The total work experiance in years determine how experianced/ proficient an employee can be. total work experiance ranges from 0 to 40.
#
#
# 21. **TrainingTimesLastYear**:This attribut quantifies the number of times an employee was trained. range 0-6.
#
#
# 22. **EmpWorkLifeBalance**: This attribute ranges from 1 to 4. 1 being "bad work life balance" and 4 being "the best work life balance"
#
#
# 23. **ExperienceYearsAtThisCompany**:This column quantifies the number of years an employee has been working for INX Future inc, this attribute can explain the comfort level and dedication of an employee with the company.
#
#
# 24. **ExperienceYearsInCurrentRole**: Experiance in the current role helps in understanding how efficient an employee is at the current role, in some cases it could also mean a very stagnant carreer specially if the employee is at base/low levels at the company.
#
#
# 25. **YearsSinceLastPromotion**:Years since last promoted can help indicate that an employees output is appreciated, when employees are appreciated the tend to outperform, in contrary hard working employees that do not see their work being appreciated/ or promoted on merit basis, tend to not perform well or seek job opportunities elsewhere.
#
#
# 26. **YearsWithCurrManager**:The relationship between an employee and their current manager can have substantial impact on the employee's performance, motivation, job satisfaction, engagement, and overall effectiveness, when managers become effective leaders and mentors the performance rating of employees also improves.
#
#
# 27. **Attrition**:Attrition rate of a company shuold always be low, higih rate could mean unhealthy work environments, or less growth prospects. These factors can affect workflow and lead to increased workloads and can negatively impact the performance of existing employees.
#
# #### Target Variable
#
# 28. **PerformanceRating**:Various factors can affect the performance Rating of an employee, such as some mentioned above (independant Attributes). the Performance Rating of Employees of INX Future Inc are in the range 1 to 4; **1- Low Performance, 2- Good, 3- Excellent, 4- Outstanding performance.**

# %% [markdown]
# ##### Importing  Necessary Libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### Importing the Excel File

# %%
# read/import Excel file
# 'd' refers to the original data imported in the form the Excel File.

d=pd.read_excel('EMPLOYEE PERFORMANCE OF INX.xls')
d
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %% [markdown]
# # Basic Checks

# %%
pd.set_option('display.max_columns',None) #to display all columns
d.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# ...

# %%
d.head() # display first 5 rows
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# ...

# %%
d.tail() # display below 5 rows
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 1195   E100992   27  Female             Medical      Divorced         Sales
# 1196   E100993   37    Male       Life Sciences        Single   Development
# 1197   E100994   50    Male             Medical       Married   Development
# 1198   E100995   34  Female             Medical        Single  Data Science
# 1199   E100998   24  Female       Life Sciences        Single         Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 1195   Sales Executive       Travel_Frequently                 3
# 1196  Senior Developer           Travel_Rarely                10
# 1197  Senior Developer           Travel_Rarely                28
# 1198    Data Scientist           Travel_Rarely                 9
# 1199   Sales Executive           Travel_Rarely                 3
#
#       EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# ...

# %%
d.info() #Gives a quick glance of the datatype,number of columns, number of rows and non-null counts etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %% [raw]
# Note:from the above information is can be seen that there is no null data

# %%
d.describe().T #displays a statistical summary
# Out:
#                                count       mean        std   min   25%   50%  \
# Age                           1200.0  36.918333   9.087289  18.0  30.0  36.0
# DistanceFromHome              1200.0   9.165833   8.176636   1.0   2.0   7.0
# EmpEducationLevel             1200.0   2.892500   1.044120   1.0   2.0   3.0
# EmpEnvironmentSatisfaction    1200.0   2.715833   1.090599   1.0   2.0   3.0
# EmpHourlyRate                 1200.0  65.981667  20.211302  30.0  48.0  66.0
# EmpJobInvolvement             1200.0   2.731667   0.707164   1.0   2.0   3.0
# EmpJobLevel                   1200.0   2.067500   1.107836   1.0   1.0   2.0
# EmpJobSatisfaction            1200.0   2.732500   1.100888   1.0   2.0   3.0
# NumCompaniesWorked            1200.0   2.665000   2.469384   0.0   1.0   2.0
# EmpLastSalaryHikePercent      1200.0  15.222500   3.625918  11.0  12.0  14.0
# EmpRelationshipSatisfaction   1200.0   2.725000   1.075642   1.0   2.0   3.0
# ...

# %%
#Renaming columns
d=d.rename(columns={'EducationBackground':'Education', 'EmpDepartment':'Department', 'EmpJobRole':'JobRole', 'EmpEducationLevel':'EducationLevel', 'EmpEnvironmentSatisfaction':'EnvironmentSatisfaction', 'TotalWorkExperienceInYears':'WorkExp_Total', 'ExperienceYearsAtThisCompany':'WorkExp_Company', 'ExperienceYearsInCurrentRole':'CurrentRoleExp'})

# %%
d.head() #basic check after renaming
# Out:
#   EmpNumber  Age Gender        Education MaritalStatus       Department  \
# 0  E1001000   32   Male        Marketing        Single            Sales
# 1  E1001006   47   Male        Marketing        Single            Sales
# 2  E1001007   40   Male    Life Sciences       Married            Sales
# 3  E1001009   41   Male  Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male        Marketing        Single            Sales
#
#            JobRole BusinessTravelFrequency  DistanceFromHome  EducationLevel  \
# 0  Sales Executive           Travel_Rarely                10               3
# 1  Sales Executive           Travel_Rarely                14               4
# 2  Sales Executive       Travel_Frequently                 5               4
# 3          Manager           Travel_Rarely                10               4
# 4  Sales Executive           Travel_Rarely                16               4
#
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS - Visualization
#
# ### Exploratory data Analysis will include ; Univariate Analysis and Bivariate Analysis.
#
# **Univariate Analysis** will help understand the each column/ attribute individually, its content and count/ spread of each variable.
#
# - For these analysis **Seaborn** Library will be used as visualization tools alongside **sweetviz** for more detailed output.
# - Histogram will be used univatiate analysis using Seaborn.
#
# **Bivariate Analysis** Bivariate analysis will help determine whether there is a relationship or association between two variables. It helps answer questions like: Are these two variables related, and if so, to what extent
#
# **Multi variate analysis** multiple columns will be compared with eachother using the correlation corfficient function/ Heatmaps etc.

# %%
#shape quantifies the number of rows and columns
d.shape
# Out:
# (1200, 28)

# %%
#checking all columns and data-type of column names
d.dtypes.index
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'Education', 'MaritalStatus',
#        'Department', 'JobRole', 'BusinessTravelFrequency', 'DistanceFromHome',
#        'EducationLevel', 'EnvironmentSatisfaction', 'EmpHourlyRate',
#        'EmpJobInvolvement', 'EmpJobLevel', 'EmpJobSatisfaction',
#        'NumCompaniesWorked', 'OverTime', 'EmpLastSalaryHikePercent',
#        'EmpRelationshipSatisfaction', 'WorkExp_Total', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'WorkExp_Company', 'CurrentRoleExp',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition',
#        'PerformanceRating'],
#       dtype='object')

# %%
# drop EmpNumber: the employee Number works as a unique identification key for each employee 
# this column and will not provide valuable insights to the analysis.

d.drop('EmpNumber',axis=1,inplace=True)

# %%
d.shape #columns reduced to 27 columns from 28.
# Out:
# (1200, 27)

# %%
d
# Out:
#       Age  Gender        Education MaritalStatus       Department  \
# 0      32    Male        Marketing        Single            Sales
# 1      47    Male        Marketing        Single            Sales
# 2      40    Male    Life Sciences       Married            Sales
# 3      41    Male  Human Resources      Divorced  Human Resources
# 4      60    Male        Marketing        Single            Sales
# ...   ...     ...              ...           ...              ...
# 1195   27  Female          Medical      Divorced            Sales
# 1196   37    Male    Life Sciences        Single      Development
# 1197   50    Male          Medical       Married      Development
# 1198   34  Female          Medical        Single     Data Science
# 1199   24  Female    Life Sciences        Single            Sales
#
#                JobRole BusinessTravelFrequency  DistanceFromHome  \
# 0      Sales Executive           Travel_Rarely                10
# ...

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
#using Seaborn as the Visualization tool

plt.figure(figsize=(10, 70), facecolor='white')
plotnumber = 1

# List of variables to rotate x-axis labels
rotate_labels = ['JobRole', 'EmpHourlyRate','Education', 'WorkExp_Total', 'Department']

for column in d:
    if plotnumber <= 27:  # 27 attributes
        ax = plt.subplot(14, 2, plotnumber)  # 2 attributes in each of the 14 rows
        sns.countplot(data=d, x=column)
        plt.xlabel(column, fontsize=20)
        plt.ylabel('Count', fontsize=10)
        
        if column in rotate_labels:
            plt.xticks(fontsize=7, rotation=90)
        else:
            plt.xticks(fontsize=10)

    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
#plotting the count of Hourly Rate for better view point.
plt.figure(figsize=(20,10))
sns.countplot('EmpHourlyRate',data=d)
plt.xticks(rotation='vertical')
plt.xlabel('Employee Hourly Rate',fontsize=20)
plt.show()

# %%
import sweetviz as sv #importing the sweetviz library 
my_report = sv.analyze(d) #syntax to use sweetviz
my_report.show_html() #Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |                                                                …
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Unvariate Analysis -A  Quantitative summary
#
# 1. **Age** of Employees range between 18 and 60, with the average age being 36-37
#
#
# 2. **Gender**: 60% of the employees are Male, and 40% Female
#
#
# 3. **Education**: more tahn 40% of the employees are educated in the field of Life sciences, followed by, medical,marketing, technical degree and more the 5% belong to other streams.
#
#
# 4. **Maritial Status** is as follows; about 45% of the employee are Married, more than 30% single and more than 20% Divorced.
#
#
# *5. About 30% of INX Work force is in sales, almost 60% is in research & development + Development combined(29+30). About less than 5% in Human Resourses department, and only about about 6-7% belong to other **departments**.
#
#
# 6. In the **Job role** segment, more than 20% employees are sales executives holding the hightst percentage, followed by Developers with almost 20% of the workforce, a little less than 10% are R&D managers, over 5% are research Scientist, while the rest other roles in accumulation form above 40% of the total.
#
#
# 7. **Travel Frequency**: about 65% employees rarely travel, less than 20% travel frequently and about 10% are non travellers.
#
#
# 8. The **Minimum Distance from home** to the company travelled by an employee is 1 Km (assuming Kilometers) and the maximum being 29Km. while on a average employees travel 9.2Km, and has a median 7Km.
#
#
# 9. when is comes to **Education Level** more than 35% have a Bachelors Degree (markes as level 3), more tahn 25% hold a Masters (marked as level 4), 20% have completed College (level 2) , more than 10% have completed a Below College level education (level 1), and a small proportion of the employees hold a doctorate degree.
#
#
# 10. **Environmental Satisfaction & Job satisfaction**:above 30% of the employees say that their satisfaction level is 'High'(3), 30% are'Very Highly'satisfied(4),20% say they have a medium satisfaction level(2), a slightly smaller proportion of employees have rated theiR satisfaction level 'low'(1).  More than 30% have rated their Job Satisfaction 4 (very high), 30% rated 3 (high), about 20% rated theirs satisfaction a 2 (medium), and 19% rater 1 (low)
#
#
# 11. The Maximum *Hourly Rate* is 100 (assuming Indian Rs) and min is 30 Rs, while on an average employees are paid Rs 66 per hour.
#
#
# 12. **Job Involvement** : 60% of the employees have a 'high' job involvement (3), above 20% show medium involvement (marked 2), about 10% show very high involvement (4), below 5% interact to least.
#
#
# 13. **Job Level**: about 70% of the employees belong to the lower level management(1 and 2), 14% belong to the middle level (3), and 8% belong to a higher level and only 5% comprise the topmost level of management.
#
#
# 14. Number of companies worked : more tha 30% employees have worked in 1 other company before joining INX, 13% have started their first job at INX, and about 5%. And about 30% of the employess have worked with 4 to 9 companies before joining INX.
#
#
# 15. about 70% of the employess **work overtime** and and the rest do not
#
#
# 16. the highest **last salary hike** of an employee is 25%, and the least was 11, while on an average the hike % at INX 14 to 15.2%
#
#
# 17. The **Employee Relationship Satisfaction** is rated 3 and 4 mostly (32% and 30%), whereas 20% rated it a 2 (medium), and 18% rated it 1 i.e. low.
#
#
# 18.
# a. The highest **total work experiance** of an employee at INX is 40 years, and minimum 0 years. on a average employees have a total work experiance of 10 to 11.3 %.
# b. where as the average  work **experiance in years with INX** is 5-7 years.
# c. when it comes to experiance at the current role, employees have a maximul of 18 and minimum of 0 years with the average being 3 to 4.3 years.
# d. **years with Current Manager** : the maximum years an employee had worked with its current manager is 17. with an average of 3 yo 4 years.
# (Note: there seems to be high correlation amongst the above (point 19) attributes)
#
#
# 19. The Highest number of **Train Times** last year was, 2 (37% of employees), followed by 3 times, 16% of the employees were trained 4 to 5 times. and 8% of the employees were trained 0 times and 6 times in total.
#
#
# 20. 5% of the employees have a 'bad' **work life balance** (rated 1),  60% have a better work life balance (rated 3), 24% have rated it a 2 (good balance).
#
#
# 21. a small percentage of the employees were **previously promoted** in the last 8 to 15 years, whereas about 40% and 30% of the employees where last promoted in less than 1 year and 1 year respectively.
#
#
# 22. **Attrition**: This attribute indicates that 85% of the employees in the organization have not left their positions where as 15% have left organization/organizations.
#
#
# 23. More than 73% of the employees have a **Performance Rating** of 3 that is Excellent, More than 15% have a rating of 2 (good), more than 10% have an outstanding rating of 4 with is the highest and none of the have a low rating of 1.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# This will cover **Task 1**
#
# seaborn/matplotlib will be used for Bivariate Analysis

# %% [markdown]
# # Task 1. To Project Department wise performances

# %%
d.Department.unique()
# Out:
# array(['Sales', 'Human Resources', 'Development', 'Data Science',
#        'Research & Development', 'Finance'], dtype=object)

# %% [markdown]
# **Assumptions: Research & Development and  Development (Assuming an entry Error), fall under the same umbrella, and and can be clubbed as 1 department i.e. Research and Development**
#
# Note: before merging the two, Development has 30% of the employees under it, and Research & Development has 29%
# after merging, Department will also be named as Research & Development will have about 60% of the work force under it ( 59% to be precise)

# %%
# Merging Development and Research & Development to Research and Development  
d['Department'] = d['Department'].replace({'Development': 'Research & Development'})

d.Department.unique() #Displaying the new list of unique values under department.
                      #now there are 5 unique values
# Out:
# array(['Sales', 'Human Resources', 'Research & Development',
#        'Data Science', 'Finance'], dtype=object)

# %%
# Finding the mean performance of all the departments

department_Avg_Performance = d.groupby('Department')['PerformanceRating'].mean()  
print(department_Avg_Performance )
# Out:
# Department
# Data Science              3.050000
# Finance                   2.775510
# Human Resources           2.925926
# Research & Development    3.005682
# Sales                     2.860590
# Name: PerformanceRating, dtype: float64

# %% [markdown]
# Data Scientist, Research & Development, Human Resources Department  have the highest mean rating, while sales and finance have the lowest average Performance rating.

# %%
#creating a new dataset for Depatrment and its PerformanceRating

# List of unique departments names
departments = d['Department'].unique()

# Unique Values in performance ratings
performance_ratings = d['PerformanceRating'].unique()

# Create separate bar plots for each department
plt.figure(figsize=(15, 15))

for i, department in enumerate(departments):
    department_data = d[d['Department'] == department]
    plt.subplot(3, 2, i + 1)  # 3 rows, 2 columns, i+1 indicates the subplot number

    # Count the number of occurrences for each performance rating
    rating_counts = department_data['PerformanceRating'].value_counts()

    # Create a pie chart for the department
    plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title(f'{department} Department')    #To add department after each department name
    plt.legend()  #to view the colors assigned to each of the rating
plt.show()

# %% [markdown]
# ## Task 1 - Summary
# Assumptions: Research & Development and Development (assuming an entry Error), fall under the same umbrella, and and can be clubbed as 1 department i.e. Research and Development
#
# Note: before merging Development costituted 30% of the employees, and Research & Development had 29% after merging, Department was named as Research & Development and has about 60% of the total proportion from the overall departments ( 59% to be precise)
#
# Performance Rating scale: 1-Low, 2-Good, 3-Excellent, 4-Outstanding.  #for reference
#
# **A.** Average Performance Rating of Departments:  After calculating the Mean of all the 5 departments, it is observed that all departments have an approximate average Rating of 3, that is 'Excellent'. to be precise, the Data Science Department had the highest average rating of 3.05 followed by Research and development with 3 as the average,while and Human Resources, Sales and Finance rated 2.93, 2.86 and 2.77 on an average respectively.
#
# **B.** On plotting each department performance saperately, we can observe the same, i.e. **3-'Excellent'** had the highest count/mode across all departments.
# - Employees from the  **Research and Development** and the **Human Resourse Department** have the highest 'Outstanding' rating i.e. above 11%, whereas the **Data science department** has the least percent of 'outstanding' rating, 5% , On the brighter side its employees have the highest excellent rating.
# - In contrary employees of the **Finance** and the **sales** Department have hightes rating of '2' in comparison to the other departments in the organization (31% and 23% respectively) . although 2 is a 'GOOD' rating, it is important to note that it is the lowest Rating given. and no employee is given the rating 1
#
# this can also be seen as a major Drawback of this analysis, as No employee is given a rating of 1, which makes it difficult for the company to provide adequate training and counseling to perform better or to catch hold of the non performing employees.

# %% [markdown]
# ### Bivariate Analysis of Independent Variables

# %%
# Bivariate Analysis 1 

plt.figure(figsize=(12, 10))
# 2 row, 2 columns

# Plot for PerformanceRating
plt.subplot(2, 2, 1) 
sns.lineplot(x='Age', y='Attrition', data=d, color="orange")
plt.xlabel('Age', fontsize=10)
plt.title('Age Groups v/s Attrition', fontsize=15)

# Overall Job Levels held by Male & Female
plt.subplot(2, 2, 2) 
sns.barplot(x='Gender', y='EmpJobLevel', data=d, color="blue")
plt.xlabel('Gender', fontsize=10)
plt.title(' Overall Job Levels held by Male & Female ', fontsize=15)

# working Overtime impact on Work Life Balance
plt.subplot(2, 2, 3)  
sns.barplot(x='EmpWorkLifeBalance', y='OverTime', data=d, color="green")
plt.xlabel('Work Life Balance', fontsize=10)
plt.title(' "Working Overtime" impact on Work Life Balance ', fontsize=15)

# Average Hourly Rate of Depertments
plt.subplot(2, 2, 4)  
average_Rate = d.groupby('Department')['EmpHourlyRate'].mean().reset_index()
sns.barplot(x='Department', y='EmpHourlyRate',data=average_Rate, color="orange")
plt.xlabel('Department', fontsize=10)
plt.title('Average Hourly Rate of Depertments', fontsize=15)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Summary of Bivariate Analysis (1):
# 1. **Age V/s Attrition** :it is Observed that the attrition Rate is high among the yonger age group of employees i.e. 18 to 25 years of age
#     where as the attrition is the lowest in the late 50's age bracket.
#
# 2. **Employee Job Level v/s Gender**: it is observed that overall Female employees hold a higher job level position than their male counterparts
#
# 3. **Over Time v/s Work Life Balance**: there is a minute difference seen in the overall work life balance. employees that do not work overtime have a slightly better work life Balance overall.
#
# 4. **Performance Rating v/s Training time:** Overall the Average Hourly Rate is the Highest in the Finance Department and lowest in the Data Science Department, however as a whole the average Rate of all departments range between 60 and 70.

# %%
# Bivariate Analysis 2

plt.figure(figsize=(12, 10))

# 2 row, 2 columns

#Attrition vs NumCompaniesWorked
plt.subplot(2, 2, 1)  #1st graph
sns.lineplot(x='Attrition', y='NumCompaniesWorked', data=d, color="Blue")
plt.xlabel('Attrition', fontsize=10)
plt.title('Attrition vs No. of Companies Worked at', fontsize=15)

# Job Involvement v/s Job Satisfaction
plt.subplot(2, 2, 2)  #2nd Graph
sns.lineplot(x='EmpJobInvolvement', y='EmpJobSatisfaction', data=d, color="Red")
plt.xlabel('EmpJobInvolvement', fontsize=10)
plt.title('Job Involvement v/s Job Satisfaction ', fontsize=15)

# CurrentRoleExp v/s YearsSinceLastPromotion',
plt.subplot(2, 2, 3) #3rd Graph
sns.barplot(x='CurrentRoleExp', y='YearsSinceLastPromotion', data=d, color="green")
plt.xlabel('Current Role Exp in Years', fontsize=10)
plt.title('Experiance at Current Role v/s Years Last Promoted ', fontsize=15)

# Relation Between Environment Satisfaction and Years worked with Current Manager'
plt.subplot(2, 2, 4)  #4th graph
sns.lineplot(x='YearsWithCurrManager', y='EnvironmentSatisfaction', data=d, color="orange")
plt.xlabel('YearsWithCurrManager', fontsize=10)
plt.title('EnvironmentSatisfaction v/s Tenure with Current Manager', fontsize=15)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Summary of Bivariate Analysis (2):
#
# 1. **Attrition v/s NumCompaniesWorked** : shows a clear positive line Graph that showcases that the more the number of companies worked at will also have Attrition.
#
# 2. **Job Involvement v/s Job Satisfaction**: the line depicts that on an overall level as the Job Involvement increases the Job Satisfaction Decreases.
#
# 3. **CurrentRoleExp v/s YearsSinceLastPromotion** bar graph shows a positive Relationship i.e. as the number of years in the current role increases, the years since last promoted also increases.
#
# 4. Relation Between **Environment Satisfaction and Years worked with Current Manager** depicts that, as the years with the current manager increases, on a overall their Environment Satisfaction reach two opposit extreams i.e. very high or very low satisfaction. in contrary the fewer years with the current manager shows a medium to high satisfaction.

# %%
# Calculate overtime percentages per department
overtime_percentage_per_department = d.groupby('Department')['OverTime'].value_counts(normalize=True).unstack(fill_value=0) * 100

# Get the list of department names
departments = overtime_percentage_per_department.index

# Create two rows with three columns of pie charts
fig, axes = plt.subplots(2, 3, figsize=(18, 12))

for i in range(2):
    for j in range(3):
        department = departments[i * 3 + j] if i * 3 + j < len(departments) else None
        ax = axes[i, j]

        if department is not None:
            percentages = overtime_percentage_per_department.loc[department]
            labels = overtime_percentage_per_department.columns
            ax.pie(percentages, labels=labels, autopct='%1.1f%%', textprops={'fontsize': 20}, colors=['lightcoral', 'lightgreen'])
            ax.set_title(f'Overtime Percentage in {department}', fontsize=22)  # Increase the font size
        else:
            ax.axis('off')  # Hide empty subplots

# Adjust the layout
plt.tight_layout()
plt.show()

# %% [markdown]
# The Research and Development department and sales department employees have the highest overtime work percentage followed by Human Resources deptartment and Finance

# %%
d.EmpJobSatisfaction
# Out:
# 0       4
# 1       1
# 2       1
# 3       4
# 4       1
#        ..
# 1195    4
# 1196    4
# 1197    3
# 1198    2
# 1199    3
# Name: EmpJobSatisfaction, Length: 1200, dtype: int64

# %%
# Bivariate Analysis 3

plt.figure(figsize=(12, 10))
# 2 row, 2 columns

#Impact of Distance Travelled to office on Job Involvement
plt.subplot(2, 2, 1)  #1st graph
average_involvement = d.groupby('DistanceFromHome')['EmpJobInvolvement'].mean().reset_index()
sns.barplot(x='DistanceFromHome', y='EmpJobInvolvement',data=average_involvement, color="blue")
plt.xlabel('Distance From Home', fontsize=10)
plt.title('Impact of Distance Travelled to office Avg Job Involvement', fontsize=15)

#Impact of Total work experiance on the Hourly Rate 
plt.subplot(2, 2, 2)  #2nd Graph
sns.lineplot(x='WorkExp_Total', y='EmpHourlyRate',data=d, color="blue")
plt.xlabel('WorkExp_Total', fontsize=10)
plt.title('Impact of Total work experiance on the Hourly Rate ', fontsize=15)

# Years with Current Manager v/s Relationship Satisfaction
plt.subplot(2, 2, 3) #3rd Graph
sns.barplot(x='YearsWithCurrManager', y='EmpRelationshipSatisfaction', data=d, color="green")
plt.xlabel('Current Role Exp in Years', fontsize=10)
plt.title('Years with Current Manager v/s Relationship Satisfaction', fontsize=15)


# Business Travel Frequency v/s Average Job Satisfaction
plt.subplot(2, 2, 4)  # 4th graph
average_satisfaction = d.groupby('BusinessTravelFrequency')['EmpJobSatisfaction'].mean().reset_index()
sns.lineplot(x='BusinessTravelFrequency', y='EmpJobSatisfaction', data=average_satisfaction, color="purple")
plt.xlabel('BusinessTravelFrequency', fontsize=10)
plt.title('Business Travel Frequency v/s Average Job Satisfaction ', fontsize=15)

## Business Travel Frequency v/s Average Job Satisfaction
plt.subplot(2, 2, 4)  # 4th graph
average_satisfaction = d.groupby('BusinessTravelFrequency')['EmpJobSatisfaction'].mean().reset_index()
sns.lineplot(x='BusinessTravelFrequency', y='EmpJobSatisfaction', data=average_satisfaction, color="purple")
plt.xlabel('BusinessTravelFrequency', fontsize=10)
plt.title('Business Travel Frequency v/s Average Job Satisfaction ', fontsize=15)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Summary of Bivariate Analysis (3):
#
# 1. **Impact of Distance Travelled to office On Employee Job Involvement**: The relationship between the two attributes is almost constant. as the travel distance increases theenployee job Involvement is constant between 2 to 3 i.e. medium to high
#
# 2. **Impact of Total work experiance on the Hourly Rate**: it is observed that as the total work experiance increases, the hourly rate has bothe extremes of high Rate as well as Low. in contrary the lower the total work experiance is, the more constant and concentrated the hourly rate is 60-70 Rs.
#
# 3. **Years with Current Manager v/s Relationship Satisfaction**: shows an almost constant but slightly upward trend betweent the two attributes(between 2.5 to 3.5). however at 16 years of work experiance the relations satisfaction rating dropped drastically to 1 (low), this may be considered an outlier.
#
# 4. **Business Travel Frequency v/s Average Job Satisfaction**: Employees with high Business Travel Frequency show a higher 'average' job satisfaction, non Travellers show a lower satisfastion rating and those who travel rarely have the lowest Average satisfaction. however the average ratings range between 2.70 and 2.82 that is , Medium to high.

# %%
# list of independent variables v/s Performance Rating(X)
independent_variables = ['Age', 'Gender', 'Education','MaritalStatus', 'JobRole', 'BusinessTravelFrequency', 'DistanceFromHome', 'EducationLevel', 'EnvironmentSatisfaction', 'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel', 'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime', 'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction', 'WorkExp_Total', 'TrainingTimesLastYear', 'EmpWorkLifeBalance', 'WorkExp_Company', 'CurrentRoleExp', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition']

# Create a custom color palette based on the specified scale
def custom_palette(val):
    if val <= 2.6:
        return 'red'
    elif val > 2.6 and val <= 3.0:
        return 'blue'
    elif val > 3.0 and val <= 4.0:
        return 'green'

# figure size and number of subplots
plt.figure(figsize=(10, 70))  # Adjust the figure size as needed
num_subplots = len(independent_variables)

for i, variable in enumerate(independent_variables, start=1):
    plt.subplot(13, 2, i)  # 13 rows, 2 columns for the specified variables
    avg_perform = d.groupby(variable)['PerformanceRating'].mean().reset_index()
    
    sns.barplot(data=avg_perform, x=variable, y='PerformanceRating', ci=None, palette=[custom_palette(x) for x in avg_perform['PerformanceRating']])
    plt.title(f'Performance Rating and {variable}')
    plt.xlabel(variable)
    plt.ylabel('Performance Rating')
    if variable in ['JobRole', 'EmpHourlyRate','WorkExp_Total']:
        plt.xticks(fontsize=7, rotation=90)
    else:
        plt.xticks(fontsize=10)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bivariate Analysis -A  Quantitative summary
#  **Average Performance ratings lesser and equal to 2.6 are marked in Red,
#  **Agerage values between 2.6 and 3. and below are marked Blue
#  ** and the rest between 3.0 and abover are categorized with the color green
#
# 1. **Age** the minimun and maximum tails of the age group have a higher Performance Rating as compared to those in between.
# 2. in the **JobRole** category, Business Analysts Senior Data Scientists, Developers and Technical Leads have an average rating of 3 and above i.e excellent and Outstanding.
# 3. **Environment Satisfaction** those with an Environment Satisfaction of 3 & 4 have an Excellent-Outstanding Performance Rating
# 4. The **EmpJobLevel** shows an Average Performance Rating of 3 with a slight decline as the Job Level increases.
# 5. **NumCompaniesWorked**: employees who have worked with 4 companies overall have shown an Excelent performance rating, that probably comes with their eexpertise. where as those with more/less than 4 have a lower rating
# 6. **EmpLastSalaryHikePercentage**: Employees with their last hike in Salary of 20% and above have shown an above 3 Performance rating throughout. this indicates that more the hike in salary better is the performance
# 7. **WorkExp_Total** employees with Total work experiance at the company initially (from 1-12 years) and towards the end (31-34) have shown spikes in performance, however employees with 37 years of experiance with the company have shown a steep Decline in output.
# 8. **EmpworkLifeBalance**: there is a noticeable incline in ther performance rating as the work life Balance increases, the employees with the best work life balance have an Excelent performance rating
# 9. **WorkExp_Company**: between 32 and 23 years of company experiance there are multiple drops in the performance, wheres there are multiple spikes in performance below 8 years experiance and above 22 years of work experiance with the company.
# 10. **Current Role Experiance** shows a drop in average performance rating at 14 and 16 years
#
# 11. **YearsSinceLastPromoted** and **YearsWithCurrentManager** indicates an Excelent Performance in the Begining years and towards the end. however there is a drop in the performance rating between 8 and 12 years 'since an employee was last promoted'. and a similar drop is visible in 'Years with current manager' between 12 to 14 years.
#
# No Significant pattern seen in;
#
# **Gender** ( both male and felmale have a avg Performance rating of 3), **Education**,**EducationLevel**, **Maritial Status**, **jobInvolvement**, **EmpJobSatisfaction**,**EmpRelationshipSatisfaction** of employee also show an average Rating of 3. **Distance from Home**, **TrainingTimeLastYear** aslo shows a constant output, however beyond 16Km distance there is no average porformance exceeding  3. **HourlyRate** also has an almost constant Rating however at the rate of 52 there is a performance decline of 2.6 and below. employees that work **Overtime** shows a higher, however, negligible rating. employees with a record of **Attrition** indicated a slight dip in performance in contrary to those who do not.

# %% [markdown]
# # Data Pre-Processing
# - Checking for Null/repeated values -  no null and duplicate values.
# - Outliers
# - Dropping unnecessary columns: correlation.

# %%
#Checking for duplicate Values
duplicates = d.duplicated()

# to view rows that are duplicates
duplicate_rows = d[duplicates]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education, MaritalStatus, Department, JobRole, BusinessTravelFrequency, DistanceFromHome, EducationLevel, EnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, WorkExp_Total, TrainingTimesLastYear, EmpWorkLifeBalance, WorkExp_Company, CurrentRoleExp, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []

# %% [markdown]
# ### Encoding data using - LableEncoder
# The data that is Categorical in Nominal/Ordinal form will be encoded using LableEncoder. and will be given values 0,1,2,3, and so on
# -Columns t bo encoded: Education, Gender, OverTime, Department, JobRole, BusinessTravelFrequency, MaritalStatus, Attrition.

# %%
#Importing LabelEncoder 
from sklearn.preprocessing import LabelEncoder

# %%
# creating a list of nominal Data and encoding them
categorical_cols = ['Education', 'Gender', 'OverTime', 'Department', 'JobRole', 'BusinessTravelFrequency', 'MaritalStatus', 'Attrition']  

lc = LabelEncoder()
d[categorical_cols] = d[categorical_cols].apply(lc.fit_transform)  
#converted nominal to discrete

# %%
# encoding target variable.
col_y = ['PerformanceRating']  

lc = LabelEncoder()
d[col_y] = d[col_y].apply(lc.fit_transform)

# %%
#2 renamed 0, 3 renamed 1, 4 renamed 2
d.PerformanceRating.unique()
# Out:
# array([1, 2, 0], dtype=int64)

# %%
sns.countplot('PerformanceRating', data=d)
plt.title('New Distribution of Performance Rating - Target variable')
plt.show()

# %% [markdown]
# Summary:
# 1. No null values, checked under basic checks.
# 2. No Duplicated entries.
# 3. Categorical Nominal/Ordinal Columns such as, Education, Gender, OverTime, Department, JobRole, BusinessTravelFrequency, MaritalStatus, Attrition are encoded using LableEncoder

# %% [markdown]
# ### Finding Outliers - Using Box Plot
# (can be used on numeric attributes)
# - imputing outliers below 1.5%
# - 1.5 % since the attributes have "almost" discrete columns as the count of unique values are known and have a limited range and not necessarily continuous.
# therefore to avoid information loss the threshold limit in this case will be 1.5%

# %%
# Checking for outliers
plt.figure(figsize=(18,25), facecolor='white')
plotnumber = 1

for column in d:
    if plotnumber<=27 :   #for all
        ax = plt.subplot(9,3,plotnumber) #9X3= 27 , 3 columns and 9 rows
        sns.boxplot(d[column]) 
        plt.xlabel(column,fontsize=25)
        
    plotnumber+=1

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Inter Quartile Range
# To find the outlier percentage in the respective columns
#
# Note: 7 Columns are found with outliers. column Name:columns with outliers: NumCompaniesWorked, TrainingTimesLastYear, WorkExp_Total, WorkExp_Company,CurrentRoleExp,YearsWithCurrManager, YearsSinceLastPromotion

# %%
from scipy import stats
#importing IQR frim scipy, stats library

# %%
#1.NumCompaniesWorked -to check if there are less than 1.5% outliers and impute them with median

iqr = stats.iqr(d['NumCompaniesWorked'],interpolation='midpoint')
print("IQR:",iqr)

# Getting first & third quantile
Q1 = d['NumCompaniesWorked'].quantile(0.25)
Q3 = d['NumCompaniesWorked'].quantile(0.75)

# Get maximum and minimum limit
min_limit = Q1 - 1.5*iqr
print("Minimum limit:",min_limit)

max_limit = Q3 + 1.5*iqr
print("Maximum Limit:",max_limit)

outliers = d[(d['NumCompaniesWorked'] > max_limit )]
 # | (d['NumCompaniesWorked'] < min_limit)] for the lowerlimit 
outlier_percentage = (len(outliers) / len(d)) * 100

print(f"Percentage of outliers before imputing: {outlier_percentage:.2f}%")
# Out:
# IQR: 3.0
# Minimum limit: -3.5
# Maximum Limit: 8.5
# Percentage of outliers before imputing: 3.25%

# %%
#2.TrainingTimesLastYear- -to check if there are less than 1.5% outliers and impute them with median

iqr = stats.iqr(d['TrainingTimesLastYear'],interpolation='midpoint')
print("IQR:",iqr)

# Getting first & third quantile
Q1 = d['TrainingTimesLastYear'].quantile(0.25)
Q3 = d['TrainingTimesLastYear'].quantile(0.75)

# Get maximum and minimum limit
min_limit = Q1 - 1.5*iqr
print("Minimum limit:",min_limit)

max_limit = Q3 + 1.5*iqr
print("Maximum Limit:",max_limit)

outliers = d[(d['TrainingTimesLastYear'] > max_limit )]|(d['TrainingTimesLastYear'] < min_limit) #for the lowerlimit 
outlier_percentage = (len(outliers) / len(d)) * 100

print(f"Percentage of outliers before imputing: {outlier_percentage:.2f}%")
# Out:
# IQR: 1.0
# Minimum limit: 0.5
# Maximum Limit: 4.5
# Percentage of outliers before imputing: 12.00%

# %%
#3.WorkExp_Total -to check if there are less than 1.5% outliers and impute them with median

iqr = stats.iqr(d['WorkExp_Total'],interpolation='midpoint')
print("IQR:",iqr)

# Getting first & third quantile
Q1 = d['WorkExp_Total'].quantile(0.25)
Q3 = d['WorkExp_Total'].quantile(0.75)

# Get maximum and minimum limit
min_limit = Q1 - 1.5*iqr
print("Minimum limit:",min_limit)

max_limit = Q3 + 1.5*iqr
print("Maximum Limit:",max_limit)

outliers = d[(d['WorkExp_Total'] > max_limit )]
 #| (d['NumCompaniesWorked'] < min_limit)] for the lowerlimit 
outlier_percentage = (len(outliers) / len(d)) * 100

print(f"Percentage of outliers before imputing: {outlier_percentage:.2f}%")
# Out:
# IQR: 9.0
# Minimum limit: -7.5
# Maximum Limit: 28.5
# Percentage of outliers before imputing: 4.25%

# %%
#4. WorkExp_Company-to check if there are less than 1.5% outliers and impute them with median

iqr = stats.iqr(d['WorkExp_Company'],interpolation='midpoint')
print("IQR:",iqr)

# Getting first & third quantile
Q1 = d['WorkExp_Company'].quantile(0.25)
Q3 = d['WorkExp_Company'].quantile(0.75)

# Get maximum and minimum limit
min_limit = Q1 - 1.5*iqr
print("Minimum limit:",min_limit)

max_limit = Q3 + 1.5*iqr
print("Maximum Limit:",max_limit)

outliers = d[(d['WorkExp_Company'] > max_limit )]
 # | (d['NumCompaniesWorked'] < min_limit)] for the lowerlimit 
outlier_percentage = (len(outliers) / len(d)) * 100

print(f"Percentage of outliers before imputing: {outlier_percentage:.2f}%")
# Out:
# IQR: 7.0
# Minimum limit: -7.5
# Maximum Limit: 20.5
# Percentage of outliers before imputing: 4.67%

# %%
#5. CurrentRoleExp-to check if there are less than 1.5% outliers and impute them with median

iqr = stats.iqr(d['CurrentRoleExp'],interpolation='midpoint')
print("IQR:",iqr)

# Getting first & third quantile
Q1 = d['CurrentRoleExp'].quantile(0.25)
Q3 = d['CurrentRoleExp'].quantile(0.75)

# Get maximum and minimum limit
min_limit = Q1 - 1.5*iqr
print("Minimum limit:",min_limit)

max_limit = Q3 + 1.5*iqr
print("Maximum Limit:",max_limit)

outliers = d[(d['CurrentRoleExp'] > max_limit )]
 # | (d['NumCompaniesWorked'] < min_limit)] for the lowerlimit 
outlier_percentage = (len(outliers) / len(d)) * 100

print(f"Percentage of outliers before imputing: {outlier_percentage:.2f}%")
# Out:
# IQR: 5.0
# Minimum limit: -5.5
# Maximum Limit: 14.5
# Percentage of outliers before imputing: 1.33%

# %%
#imputing CurrentRoleExp outliers with median since it is less than 1.5%
d.loc[d['CurrentRoleExp'] > max_limit,'CurrentRoleExp']=d['CurrentRoleExp'].median()
d.loc[d['CurrentRoleExp'] > max_limit]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education, MaritalStatus, Department, JobRole, BusinessTravelFrequency, DistanceFromHome, EducationLevel, EnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, WorkExp_Total, TrainingTimesLastYear, EmpWorkLifeBalance, WorkExp_Company, CurrentRoleExp, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []

# %%
#6. YearsWithCurrManager-to check if there are less than 1.5% outliers and impute them with median

iqr = stats.iqr(d['YearsWithCurrManager'],interpolation='midpoint')
print("IQR:",iqr)

# Getting first & third quantile
Q1 = d['YearsWithCurrManager'].quantile(0.25)
Q3 = d['YearsWithCurrManager'].quantile(0.75)

# Get maximum and minimum limit
min_limit = Q1 - 1.5*iqr
print("Minimum limit:",min_limit)

max_limit = Q3 + 1.5*iqr
print("Maximum Limit:",max_limit)

outliers = d[(d['YearsWithCurrManager'] > max_limit )] #right limit #| (d['NumCompaniesWorked'] < min_limit)  for the left limit
outlier_percentage = (len(outliers) / len(d)) * 100

print(f"Percentage of outliers before imputing: {outlier_percentage:.2f}%")
# Out:
# IQR: 5.0
# Minimum limit: -5.5
# Maximum Limit: 14.5
# Percentage of outliers before imputing: 0.92%

# %%
#imputing YearsWithCurrManager outliers with median since it is less than 1.5%
d.loc[d['YearsWithCurrManager'] > max_limit,'YearsWithCurrManager']=d['YearsWithCurrManager'].median()
d.loc[d['YearsWithCurrManager'] > max_limit]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education, MaritalStatus, Department, JobRole, BusinessTravelFrequency, DistanceFromHome, EducationLevel, EnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, WorkExp_Total, TrainingTimesLastYear, EmpWorkLifeBalance, WorkExp_Company, CurrentRoleExp, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []

# %%
#7. YearsSinceLastPromotion-to check if there are less than 1.5% outliers and impute them with median

iqr = stats.iqr(d['YearsSinceLastPromotion'],interpolation='midpoint')
print("IQR:",iqr)

# Getting first & third quantile
Q1 = d['YearsSinceLastPromotion'].quantile(0.25)
Q3 = d['YearsSinceLastPromotion'].quantile(0.75)

# Get maximum and minimum limit
min_limit = Q1 - 1.5*iqr
print("Minimum limit:",min_limit)

max_limit = Q3 + 1.5*iqr
print("Maximum Limit:",max_limit)

outliers = d[(d['YearsSinceLastPromotion'] > max_limit )]|(d['NumCompaniesWorked'] < min_limit) 
outlier_percentage = (len(outliers) / len(d)) * 100

print(f"Percentage of outliers before imputing: {outlier_percentage:.2f}%")
# Out:
# IQR: 3.0
# Minimum limit: -4.5
# Maximum Limit: 7.5
# Percentage of outliers before imputing: 7.33%

# %% [markdown]
# #### Outliers summary
# Outliers in most of the attributes were above 1.5% threshold this information in this case is vital since attributes have "almost" discrete columns as the count of unique values are known and have a limited range of unique values and are not necessarily continuous. Therefore to avoid information loss the threshold limit in this case is kept to be 1.5%
#
# However out of the 7 attributes 2 were found with outliers below 1.5% > YearsWithCurrManager and CurrentRoleExperiance hence were imputed with the median.

# %% [markdown]
# ### Multi Variate Analysis

# %%
# checking for Correlation amongst continuous data using heat maps (for illusteration purpose)

# Selecting only the continuous variable columns
ContinuousAttributes = ['Age', 'Education', 'DistanceFromHome', 'EmpHourlyRate', 'WorkExp_Total', 'WorkExp_Company', 'CurrentRoleExp', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
continuousAttributesColumn = d[ContinuousAttributes]

# Creating a correlation matrix for selected continuous variable columns
correlation_matrix = continuousAttributesColumn.corr()

# Create a heatmap for the correlation matrix
plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Note:There is no high correlation (correlation coefficient of 0.80- 1) between continuous variables.

# %%
#checking correlation with the Target variable "PerformanceRating"
d.corr()
# Out:
#                                   Age    Gender  Education  MaritalStatus  \
# Age                          1.000000 -0.040107  -0.055905      -0.098368
# Gender                      -0.040107  1.000000   0.009922      -0.042169
# Education                   -0.055905  0.009922   1.000000      -0.001097
# MaritalStatus               -0.098368 -0.042169  -0.001097       1.000000
# Department                  -0.030338 -0.017466  -0.037724       0.091063
# JobRole                     -0.037665  0.011332  -0.012325       0.038023
# BusinessTravelFrequency      0.040579 -0.043608   0.012382       0.028520
# DistanceFromHome             0.020937 -0.001507  -0.013919      -0.019148
# EducationLevel               0.207313 -0.022960  -0.047978       0.026737
# EnvironmentSatisfaction      0.013814  0.000033   0.045028      -0.032467
# EmpHourlyRate                0.062867  0.002218  -0.030234      -0.013540
# EmpJobInvolvement            0.027216  0.010949  -0.025505      -0.043355
# ...

# %% [markdown]
# ### Columns with low Correlation Coefficient
# 1. Dropped columns with a low correlation coefficient with the target 'PerformanceRating': threshold limit of +/- 0.05 (5%) and below to avoid information loss;
# Gender, Education, EmpJobInvolvement, EmpRelationshipSatisfaction, EmpJobSatisfaction, TrainingTimesLastYear.
#
#  (Work Experiance: among WorkExp_Total (-0.068) and WorkExp_Company(-0.111), The total work experiance also includes 'years worked in the company INX', since they bot have a high correlation with the target, it will be retained), and furthere extraction will be done using PCA.
#
# #### **  **After conducting the chi square test, the final decision to drop columns will be made .** **

# %% [markdown]
# # Feature Engineering
# Feature Engineering will cover **Task 2**
#
# ### Feature Transformation: Standardization (StandardScalar)
# - It standardizes or scales features of the dataset, with a mean as 0
# - columns that require scaling are; 'Age','DistanceFromHome', 'EmpHourlyRate', 'EmpLastSalaryHikePercent', 'WorkExp_Total', 'WorkExp_Company', 'CurrentRoleExp', 'YearsSinceLastPromotion','YearsWithCurrManager'.
#
# ### Feature Selection: Chi sq
# - Chi square test will check the association between categorical variables,
# - if the association with the target is low, the variables will be dropped.
#
#
# ### Feature Extraction : Principal Component Analysis 'PCA'
# - PCA uses the orthogonal technique to extract maximum information in a lower dimension by following various patterns in data and extracts important features.

# %% [markdown]
# #### Splitting the data into x-independant variables and y-dependant variable.

# %%
## Defining X and y and creating dependent and independent variables
x = d.drop(columns = ['PerformanceRating']) ## independent variable
y = d['PerformanceRating'] ## Dependent or target variable or the variable which we have to predict

# %%
x.shape #displays dimension :1200rows and 21 columns
# Out:
# (1200, 26)

# %%
y.shape
# Out:
# (1200,)

# %% [markdown]
# ### Feature Transformation: Standardization (StandardScalar)

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler() # object creation 
x_scaled = scaler.fit_transform(x)# scaling independent variables

# %%
d #checking data afer scaling
# Out:
#       Age  Gender  Education  MaritalStatus  Department  JobRole  \
# 0      32       1          2              2           4       13
# 1      47       1          2              2           4       13
# 2      40       1          1              1           4       13
# 3      41       1          0              0           2        8
# 4      60       1          2              2           4       13
# ...   ...     ...        ...            ...         ...      ...
# 1195   27       0          3              0           4       13
# 1196   37       1          1              2           3       15
# 1197   50       1          3              1           3       15
# 1198   34       0          3              2           0        1
# 1199   24       0          1              2           4       13
#
#       BusinessTravelFrequency  DistanceFromHome  EducationLevel  \
# 0                           2                10               3
# ...

# %% [markdown]
# ### Feature Selecton: Chi square Test
# - to check association between independant variable and target

# %%
#importing Chi2 , and SelectKBest
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

bestfeatures = SelectKBest(score_func=chi2,k='all')
fit = bestfeatures.fit(x,y)

dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

featurescores = pd.concat([dfcolumns,dfscores],axis=1)
featurescores.columns = ['feature_names','Scores']

print(featurescores.nlargest(27,'Scores'))
# Out:
#                   feature_names      Scores
# 16     EmpLastSalaryHikePercent  297.136917
# 23      YearsSinceLastPromotion  238.004284
# 21              WorkExp_Company  133.602068
# 9       EnvironmentSatisfaction  110.691319
# 24         YearsWithCurrManager   98.277630
# 22               CurrentRoleExp   81.758428
# 18                WorkExp_Total   41.593037
# 5                       JobRole   35.896167
# 7              DistanceFromHome   18.650010
# 10                EmpHourlyRate   17.869736
# 15                     OverTime    7.963530
# 12                  EmpJobLevel    6.270263
# 0                           Age    5.170313
# 20           EmpWorkLifeBalance    3.876506
# 25                    Attrition    2.186305
# 3                 MaritalStatus    1.232011
# 14           NumCompaniesWorked    1.208359
# 6       BusinessTravelFrequency    1.011364
# 4                    Department    0.633975
# 19        TrainingTimesLastYear    0.407106
# ...

# %% [markdown]
# **Summary**:Features with the highest association with the target are
# - EmpLastSalaryHikePercent
# - YearsSinceLastPromotion
# - WorkExp_Company
# - EnvironmentSatisfaction
# - YearsWithCurrManager
# - CurrentRoleExp
# - WorkExp_Total
# - JobRole
# - DistanceFromHome
# - EmpHourlyRate
# - OverTime
# - EmpJobLevel
#
#
#  these columns can be retained, while the others will be dropped.

# %% [markdown]
# Columns with low Correlation Coefficient:
# Dropping columns with a **low correlation coefficient** with the target 'PerformanceRating': threshold limit of +/- 0.05 (5%) and below to avoid information loss;
# **Age**, Gender, Education, MaritalStatus, Department, BusinessTravelFrequency, **DistanceFromHome**, EducationLevel, EmpHourlyRate, EmpJobInvolvement, EmpJobSatisfaction , NumCompaniesWorked, EmpRelationshipSatisfaction, TrainingTimesLastYear, Attrition
#
# columns that will be dropped with respect to the **low chi Square** scores are:
#  **EmpWorkLifeBalance**, Attrition, MaritalStatus, NumCompaniesWorked, BusinessTravelFrequency, Department, TrainingTimesLastYear    , EmpRelationshipSatisfaction, EducationLevel, EmpJobInvolvement, Education, **EmpJobLevel,** EmpJobSatisfaction,  Gender.
#
# Age, DistanceFromHome, EmpHourlyRate have a low correlation, however DistanceFromHome, EmpHourlyRate  will not be dropped only on the basis of correlation as they have a decent Chi2 score , while age has a low chi2 rate and also low correlation hence will be dropped. EmployeeWorkLifeBalance has a high correlation hence will not be dropped.
#
# ### List of cloums that will be dropped on the basis of both :Chi2, and Correlation Coefficient
# Age, Gender, Education, MaritalStatus, Department, BusinessTravelFrequency, EducationLevel, EmpJobInvolvement, EmpJobSatisfaction , NumCompaniesWorked, EmpRelationshipSatisfaction, TrainingTimesLastYear, Attrition, EmpJobLevel.

# %%
#Dropping columns with low correlation Coefficient and chi2 score

d.drop(['Age', 'Gender', 'Education', 'MaritalStatus', 'Department', 'BusinessTravelFrequency', 'EducationLevel', 'EmpJobInvolvement', 'EmpJobSatisfaction' , 'NumCompaniesWorked', 'EmpRelationshipSatisfaction', 'TrainingTimesLastYear', 'Attrition', 'EmpJobLevel'
],axis=1,inplace=True)

# %% [markdown]
# ### Task 2. List of Top 3 Important Factors effecting employee performance
#
# with respect to Correlation the following attributrs are highly correlated to the Performance of an Employee.
# 1. **EnvironmentSatisfaction**(correlation coefficient of 0.40)
# 2. **EmpLastSalaryHikePercent**(correlation coefficient of 0.33)
# 3. **YearsSinceLastPromotion**(correlation coefficient of -0.16)
#
# on the other hand, the chi2 association suggests that the below attributes have the highest Association with the Performance.
# - **a. EmpLastSalaryHikePercent  (297.136917)**
# - **b. YearsSinceLastPromotion  (238.004284)**
# - **c. WorkExp_Company  (133.602068)**
#
# These Factors show the highest correlation  and association with the Performance Rating of the employees. which means that any change in these factors will largly impact the performance of an employee
#
# EnvironmentSatisfaction and EmpLastSalaryHikePercent are positively correlated to the Performance Rating of an employee, i.e. a hike or drop in one would lead to a hike or drop in the performance rating respectively.
# on the other hand YearsSinceLastPromotion an performance rating are negatively coerrlated i.e. they have an inverse relation.
#
#
# (overall the top 5 attributes are slightly interchanged in the 2 different evaluation models.)

# %%
x = d.iloc[:,:-1]          # saperating data independant variables from target Y
y = d.PerformanceRating

# %%
x.shape
# Out:
# (1200, 12)

# %% [markdown]
# ### Feature Extraction : Principal Component Analysis 'PCA'

# %%
#importing PCA 
from sklearn.decomposition import PCA

# Object creation of pca
pca = PCA()

principlecomponent = pca.fit_transform(x) 
plt.figure(figsize=(10, 8))
sns.set_style('darkgrid')
plt.plot(np.cumsum(pca.explained_variance_ratio_),color='k')
plt.xlabel('Number of components',fontsize=15)
plt.ylabel('Variance(%)',fontsize=15) 
plt.title('Explained Variance',fontsize=15)
plt.show()

# %% [markdown]
# - PCA's goal is to reduce the dimensionality of the data while retaining as much information (variance) as possible.
# - In the above Variance v/s Number of components graph,it can be seen that Variance starts flatterning beyond 8 Components.
# - 8 PCA's will be selected for further analysis.

# %%
# Step:2 Select the components
pca = PCA(n_components=8)
pca_d = pca.fit_transform(x)

# Step:3 Make new dataframe
pca_list= pd.DataFrame(data=pca_d,columns=['pca1','pca2','pca3','pca4','pca5','pca6','pca7','pca8'])
                                        
pca_list.head()
# Out:
#         pca1       pca2      pca3      pca4      pca5      pca6      pca7  \
# 0  10.999250   1.958029  0.754413 -5.748864  0.328330 -3.131190 -4.306703
# 1  23.857431   7.897754  4.413883  0.797444  5.810577 -3.378004 -3.843709
# 2  17.949689  15.889046 -5.053005 -6.561145  0.259050  6.124251 -6.846504
# 3  -7.162014  19.239371 -0.746246 -1.659952 -2.374873 -0.232006  7.240675
# 4 -18.039038  -4.518291  7.145215 -0.159712  4.797323 -1.442876  1.053230
#
#        pca8
# 0  0.237984
# 1 -2.703591
# 2 -0.379520
# 3  1.368751
# 4 -1.131452

# %%
#saving the pca_d to a dataframe "pca_df" so it can be saved as xls file later.

pca_df= pd.DataFrame(data=pca_d,columns=['pca1','pca2','pca3','pca4','pca5','pca6','pca7','pca8'])
                  
# target veriable to preprocess dataframe for model building & evaluation
pca_df['PerformanceRating']=d.PerformanceRating

pca_df.head()
# Out:
#         pca1       pca2      pca3      pca4      pca5      pca6      pca7  \
# 0  10.999250   1.958029  0.754413 -5.748864  0.328330 -3.131190 -4.306703
# 1  23.857431   7.897754  4.413883  0.797444  5.810577 -3.378004 -3.843709
# 2  17.949689  15.889046 -5.053005 -6.561145  0.259050  6.124251 -6.846504
# 3  -7.162014  19.239371 -0.746246 -1.659952 -2.374873 -0.232006  7.240675
# 4 -18.039038  -4.518291  7.145215 -0.159712  4.797323 -1.442876  1.053230
#
#        pca8  PerformanceRating
# 0  0.237984                  1
# 1 -2.703591                  1
# 2 -0.379520                  2
# 3  1.368751                  1
# 4 -1.131452                  1

# %% [markdown]
# #### Saving the data in EXCEL Format

# %%
#to save DataFrame to an XLS file
! pip install xlwt

# %%
#now the data can be saved in xls format.
pca_df.to_excel('PCA_EMPLOYEE_PERFORMANCE_OF_INX.xls', index=False)

# Reading new preprocess csv file
df = pd.read_excel('PCA_EMPLOYEE_PERFORMANCE_OF_INX.xls')

# Get first five rows 
df.head()

#data saved for future reference.
# Out:
#         pca1       pca2      pca3      pca4      pca5      pca6      pca7  \
# 0  10.999250   1.958029  0.754413 -5.748864  0.328330 -3.131190 -4.306703
# 1  23.857431   7.897754  4.413883  0.797444  5.810577 -3.378004 -3.843709
# 2  17.949689  15.889046 -5.053005 -6.561145  0.259050  6.124251 -6.846504
# 3  -7.162014  19.239371 -0.746246 -1.659952 -2.374873 -0.232006  7.240675
# 4 -18.039038  -4.518291  7.145215 -0.159712  4.797323 -1.442876  1.053230
#
#        pca8  PerformanceRating
# 0  0.237984                  1
# 1 -2.703591                  1
# 2 -0.379520                  2
# 3  1.368751                  1
# 4 -1.131452                  1

# %%
i= df.iloc[:,:-1]          # saperating data independant variables from target Y
o = df.PerformanceRating

# %% [markdown]
# ### PCA Will not be performed as the evaluation matrices suggested a decline in evaluation scores in all models. hence will end the PCA usage here.

# %%
x.shape
# Out:
# (1200, 12)

# %%
y.shape
# Out:
# (1200,)

# %% [markdown]
# # Model Creation
# - Support Vector Classifier

# %% [markdown]
# #### Splitting the Training and Testing Data

# %%
#importing train_test_split to split the data
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,random_state=11,test_size=0.30) # 30% data given to testing

# %%
# Check shape of train and test
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape  #840+3600=1200 Original Rows and 12 columns.
# Out:
# ((840, 12), (360, 12), (840,), (360,))

# %%
# Checking is the data is hihghly imbalabced 
sns.countplot(Y_train, data=d)
plt.title('Distribution of Performance Rating - Target variable')
plt.show()

# %% [markdown]
# #### Balancing the data using SMOTE.
# SMOTE (synthetic minority oversampling technique) : used to balance imbalanced data. It will balance the class distribution by randomly increasing the minority classes examples by replicating them.
#
# In this case rating of 2 and 4 are minority classes

# %%
from imblearn.over_sampling import SMOTE #importing SMOTE
sm = SMOTE() #assigning object nam

X_train_sm,Y_train_sm = sm.fit_resample(X_train,Y_train) #SMOTE the training data, test data will be kept intact with no alteration

# %%
#Counter is a container which keeps track to how many times equivalent values are added
from collections import Counter
print("Actual Classes",Counter(y))
print("SMOTE Classes",Counter(Y_train_sm))
# Out:
# Actual Classes Counter({1: 874, 0: 194, 2: 132})
# SMOTE Classes Counter({1: 613, 0: 613, 2: 613})

# %%
# Checking the distribution of the TARGET variable after SMOTE
sns.countplot(Y_train_sm, data=d)
plt.title('Distribution of Performance Rating - Target variable')
plt.show()
#target variable is balanced

# %%
#checking for distribution in balanced data
from scipy.stats import skew
def skewedness(d):
    skewed=[]
    for i in d:
        sk=d[i].skew()
        if(sk>1.96 or sk<=-1.96):
            skewed.append(i)
    return skewed

skewedness(X_train_sm)
# Out:
# []

# %% [markdown]
# #### Model Creation

# %% [markdown]
# # 1. Support Vector Classifier

# %%
# importing Support Vector Classifier 
from sklearn.svm import SVC
svclassifier = SVC() 
svclassifier= SVC(kernel='rbf', decision_function_shape='ovr')  # 'ovr' stands for "one-vs-rest"
#train the model
svclassifier.fit(X_train_sm, Y_train_sm)
# Out:
# SVC()

# %%
# Predict output for X_test
Y_predsvc=svclassifier.predict(X_test)
Y_predsvc
# Out:
# array([1, 2, 1, 1, 1, 2, 1, 1, 1, 1, 1, 2, 1, 2, 2, 1, 1, 1, 2, 1, 0, 2,
#        1, 1, 0, 1, 2, 2, 1, 2, 1, 1, 2, 1, 2, 0, 1, 1, 2, 0, 1, 2, 1, 2,
#        1, 0, 1, 1, 0, 2, 0, 2, 1, 0, 0, 1, 0, 2, 1, 0, 1, 2, 0, 0, 1, 0,
#        1, 0, 2, 1, 1, 2, 2, 1, 1, 1, 1, 0, 1, 0, 2, 1, 1, 0, 1, 2, 1, 2,
#        0, 2, 1, 2, 2, 2, 2, 0, 1, 2, 1, 1, 0, 0, 2, 1, 2, 2, 2, 2, 2, 1,
#        0, 0, 1, 1, 1, 1, 1, 2, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 1, 0, 0, 2,
#        1, 0, 1, 1, 1, 1, 0, 2, 1, 2, 0, 0, 1, 1, 1, 1, 0, 0, 2, 0, 1, 2,
#        2, 1, 1, 0, 0, 2, 2, 1, 0, 1, 1, 1, 1, 2, 2, 1, 1, 1, 0, 2, 1, 0,
#        1, 1, 1, 2, 2, 0, 1, 2, 0, 0, 0, 1, 2, 0, 2, 2, 1, 1, 0, 2, 0, 1,
#        1, 0, 1, 1, 1, 1, 2, 2, 1, 1, 1, 0, 1, 1, 2, 1, 1, 2, 1, 1, 1, 2,
#        1, 2, 1, 0, 2, 2, 1, 2, 1, 1, 1, 1, 0, 0, 1, 1, 2, 1, 0, 0, 2, 1,
#        1, 1, 1, 2, 1, 1, 1, 0, 0, 2, 2, 0, 1, 1, 1, 1, 1, 2, 2, 2, 0, 1,
#        1, 1, 1, 1, 1, 0, 2, 0, 0, 0, 2, 2, 1, 1, 2, 1, 2, 1, 1, 0, 2, 2,
# ...

# %%
# To evaluate the model created, evaluation metrics : accruacy score, f1 score, classification report 
from sklearn.metrics import accuracy_score,classification_report,f1_score,confusion_matrix

# %%
#Accuracy Score
acc_svc=accuracy_score(Y_test,Y_predsvc)
print('Accuracy Score:',round(acc_svc, 4))

#classification Report
print(classification_report(Y_test,Y_predsvc))
# Out:
# Accuracy Score: 0.6611
#               precision    recall  f1-score   support
#
#            0       0.46      0.62      0.53        58
#            1       0.92      0.64      0.75       261
#            2       0.36      0.88      0.51        41
#
#     accuracy                           0.66       360
#    macro avg       0.58      0.71      0.60       360
# weighted avg       0.78      0.66      0.69       360

# %%
## checking cross validation score
from sklearn.model_selection import cross_val_score
scores = cross_val_score(svclassifier,X_train_sm,Y_train_sm,cv=3)
print(scores)
print("Cross validation Score:",scores.mean())
print("Std :",scores.std())
#std of < 0.05 is good.
# Out:
# [0.69168026 0.69168026 0.68352365]
# Cross validation Score: 0.6889613920609027
# Std : 0.0038450613441356465

# %% [markdown]
# #### Hyper Parameter Tuning for SVC
# Importing Grid Search CV for HyperParameter Tuning. this is done when the evaluation Scores are low and can be improved using HyperParameter Tuning
#
# Grid Search CV will create multiple iterations and find the best Hyperparameters:C and Gama value for the model.
# - C assigns penalty for missclassification and
# - Gama defines the curvature of a hyperparameter

# %%
#importing GridSearchCV for hyperparameter tunning
from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001]} 
  
svc_hp = GridSearchCV(SVC(random_state=42), param_grid, refit = True, verbose = 3,scoring='accuracy',cv=3)
  
# fitting the model for grid search
svc_hp.fit(X_train_sm, Y_train_sm)

# Make predictions on the test data
Y_svm_hp = svc_hp.predict(X_test)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV 1/3] END ....................C=0.1, gamma=1;, score=0.367 total time=   0.2s
# [CV 2/3] END ....................C=0.1, gamma=1;, score=0.374 total time=   0.2s
# [CV 3/3] END ....................C=0.1, gamma=1;, score=0.359 total time=   0.2s
# [CV 1/3] END ..................C=0.1, gamma=0.1;, score=0.543 total time=   0.1s
# [CV 2/3] END ..................C=0.1, gamma=0.1;, score=0.393 total time=   0.1s
# [CV 3/3] END ..................C=0.1, gamma=0.1;, score=0.380 total time=   0.1s
# [CV 1/3] END .................C=0.1, gamma=0.01;, score=0.695 total time=   0.1s
# [CV 2/3] END .................C=0.1, gamma=0.01;, score=0.728 total time=   0.1s
# [CV 3/3] END .................C=0.1, gamma=0.01;, score=0.716 total time=   0.1s
# [CV 1/3] END ................C=0.1, gamma=0.001;, score=0.664 total time=   0.2s
# [CV 2/3] END ................C=0.1, gamma=0.001;, score=0.636 total time=   0.1s
# ...

# %%
# Print the best parameters after tuning
print(svc_hp.best_params_)

# Print how our model looks after hyper-parameter tuning
print(svc_hp.best_estimator_)
# Out:
# {'C': 100, 'gamma': 0.01}
# SVC(C=100, gamma=0.01, random_state=42)

# %%
#the best value for C=10, and gamma=0.01,random_state=42)

svc_hp = SVC(C=10, gamma=0.01, random_state=42)
svc_hp.fit(X_train_sm, Y_train_sm)

# Make predictions on the test data
Y_svc_hp = svc_hp.predict(X_test)

# Calculate the accuracy score
acc_svc = accuracy_score(Y_test, Y_svc_hp)
print('Accuracy Score:', round(acc_svc, 4))

# Classification Report after Hyperparameter Tuning
print(classification_report(Y_test, Y_svc_hp))
# Out:
# Accuracy Score: 0.7278
#               precision    recall  f1-score   support
#
#            0       0.52      0.38      0.44        58
#            1       0.81      0.85      0.83       261
#            2       0.43      0.46      0.45        41
#
#     accuracy                           0.73       360
#    macro avg       0.59      0.56      0.57       360
# weighted avg       0.72      0.73      0.72       360

# %% [markdown]
# # 2. Logistic Regression

# %%
# Training the model
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
lr.fit(X_train_sm,Y_train_sm)
# Out:
# LogisticRegression()

# %%
# Predicting the model
Y_predlr = lr.predict(X_test)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(Y_test,Y_predlr))
print(classification_report(Y_test,Y_predlr))
# Out:
# 0.7166666666666667
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60        58
#            1       0.91      0.73      0.81       261
#            2       0.36      0.71      0.48        41
#
#     accuracy                           0.72       360
#    macro avg       0.61      0.70      0.63       360
# weighted avg       0.79      0.72      0.74       360

# %%
print(confusion_matrix(Y_test, Y_predlr))
# Out:
# [[ 39  12   7]
#  [ 27 190  44]
#  [  5   7  29]]

# %% [markdown]
# # 3. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train_sm, Y_train_sm)

default_params = dtc.get_params()

# Print the default parameters
print(default_params)
# Out:
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}

# %%
Y_preddtc = dtc.predict(X_test)

# %%
print(accuracy_score(Y_test, Y_preddtc))
print(classification_report(Y_test, Y_preddtc))
print(confusion_matrix(Y_test, Y_preddtc))
# Out:
# 0.8638888888888889
#               precision    recall  f1-score   support
#
#            0       0.84      0.74      0.79        58
#            1       0.92      0.90      0.91       261
#            2       0.62      0.80      0.70        41
#
#     accuracy                           0.86       360
#    macro avg       0.79      0.82      0.80       360
# weighted avg       0.87      0.86      0.87       360
#
# [[ 43  13   2]
#  [  8 235  18]
#  [  0   8  33]]

# %% [markdown]
# # 3.1 Decision Tree with HyperParamater Tuning

# %%
# Importing DecisionTree Classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Training the model
dtc = DecisionTreeClassifier(random_state=42, splitter='best')

parameters = {
    'min_samples_split': [1,2,3],  # Changed values
    'criterion': ['gini', 'entropy'],
    'min_samples_leaf': [1, 2,3],
    'max_features': ['auto', 'sqrt', 'log2', None],
    'max_leaf_nodes': [None,1,5,10,],
    'min_impurity_decrease': [0.0, 0.1, 0.2]
}


dt_cv = GridSearchCV(estimator=dtc, param_grid=parameters, scoring='accuracy', cv=10)
dt_cv.fit(X_train_sm, Y_train_sm)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2', None],
#                          'max_leaf_nodes': [None, 1, 5, 10],
#                          'min_impurity_decrease': [0.0, 0.1, 0.2],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [1, 2, 3]},
#              scoring='accuracy')

# %%
dt_cv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
Y_preddt_ = dt_cv.predict(X_test)

# %%
print(accuracy_score(Y_test, Y_preddt_))
print(classification_report(Y_test, Y_preddt_))
print(confusion_matrix(Y_test, Y_preddt_))
# Out:
# 0.8666666666666667
#               precision    recall  f1-score   support
#
#            0       0.87      0.78      0.82        58
#            1       0.92      0.90      0.91       261
#            2       0.60      0.80      0.69        41
#
#     accuracy                           0.87       360
#    macro avg       0.80      0.83      0.81       360
# weighted avg       0.88      0.87      0.87       360
#
# [[ 45  12   1]
#  [  6 234  21]
#  [  1   7  33]]

# %% [markdown]
# # 4. Random Forest - parallel Ensemble Technique

# %%
#import randomforest classifier
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train_sm, Y_train_sm)

default_params = rfc.get_params()

# Print the default parameters
print(default_params)
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %%
Y_predrfc = rfc.predict(X_test)
print(accuracy_score(Y_test, Y_predrfc))
print(classification_report(Y_test, Y_predrfc))
print(confusion_matrix(Y_test, Y_predrfc))
# Out:
# 0.925
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87        58
#            1       0.94      0.96      0.95       261
#            2       0.83      0.83      0.83        41
#
#     accuracy                           0.93       360
#    macro avg       0.90      0.87      0.88       360
# weighted avg       0.92      0.93      0.92       360
#
# [[ 48   9   1]
#  [  4 251   6]
#  [  0   7  34]]

# %% [markdown]
# # 4.1 Random Forest -HyperParameter Tuning (GridSearchCV)

# %% [markdown]
# **Parameters**
# - **min_samples_split**: specifies the minimum number of samples required to split an internal node in the decision tree. setting it to a higher value can make the tree simpler and more robust against overfitting, hence hyperparameter tuning is done to select the best parameter.
#
# - **criterion**:determines the function used to measure the quality of a split. it measures the impurity In classification problems, 'gini' and 'entropy', are commonly used criterias.
#
# - **min_samples_leaf**: This parameter specifies the minimum number of samples required to be at a leaf node. If, after a split, any child node has fewer samples than this value, further splitting is stopped, and it becomes a leaf node. Similar to min_samples_split, setting it to higher values can simplify the tree and reduce overfitting.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Create a Random Forest Classifier
rfc = RandomForestClassifier()
# Define the hyperparameter grid
parameters = { 'min_samples_split': [None,1,2,3,4,5,6],
              'min_samples_leaf': [1, 2,3,5],
              'criterion': ['gini', 'entropy'],
              'max_features': ['auto', 'sqrt', 'log2'],'max_depth': [None, 10, 20, 30, 40]}

# Create a GridSearchCV instance
rfc_cv = GridSearchCV(estimator=rfc, param_grid=parameters, scoring='accuracy', cv=10)

# Fit the grid search to your data
rfc_cv.fit(X_train_sm, Y_train_sm)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3, 5],
#                          'min_samples_split': [None, 1, 2, 3, 4, 5, 6]},
#              scoring='accuracy')

# %%
rfc_cv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 30,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 3}

# %%
# Predicting the model
Y_predrf = rfc_cv.predict(X_test)

# %%
print(accuracy_score(Y_test, Y_predrf))
print(classification_report(Y_test, Y_predrf))
print(confusion_matrix(Y_test, Y_predrf))
# Out:
# 0.9361111111111111
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91        58
#            1       0.95      0.97      0.96       261
#            2       0.87      0.80      0.84        41
#
#     accuracy                           0.94       360
#    macro avg       0.91      0.89      0.90       360
# weighted avg       0.94      0.94      0.94       360
#
# [[ 52   6   0]
#  [  4 252   5]
#  [  0   8  33]]

# %% [markdown]
# # 5. K-Nearest Neighbor

# %%
# Training the model
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10, metric='euclidean') # Maximum accuracy for n=10
knn.fit(X_train_sm,Y_train_sm)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=10)

# %%
# Predicting the model
Y_predknn = knn.predict(X_test)

# %%
print(accuracy_score(Y_test, Y_predknn))
print(classification_report(Y_test, Y_predknn))
print(confusion_matrix(Y_test, Y_predknn))
# Out:
# 0.5083333333333333
#               precision    recall  f1-score   support
#
#            0       0.26      0.64      0.37        58
#            1       0.85      0.46      0.60       261
#            2       0.34      0.61      0.43        41
#
#     accuracy                           0.51       360
#    macro avg       0.48      0.57      0.47       360
# weighted avg       0.70      0.51      0.54       360
#
# [[ 37  14   7]
#  [ 98 121  42]
#  [  9   7  25]]

# %% [markdown]
# # 6 XGBoost Classifier

# %%
# Training the model
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train_sm,Y_train_sm)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
# Predicting the model
Y_predxgb = xgb.predict(X_test)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(Y_test,Y_predxgb))
print(classification_report(Y_test,Y_predxgb))
# Out:
# 0.8972222222222223
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85        58
#            1       0.93      0.93      0.93       261
#            2       0.73      0.78      0.75        41
#
#     accuracy                           0.90       360
#    macro avg       0.85      0.84      0.84       360
# weighted avg       0.90      0.90      0.90       360

# %% [markdown]
# # 6.1 XGBoost Classifier - with HyperParameterTuning
# -using xgboost over gradient boost because it is computationally efficient and faster.

# %% [markdown]
# **Parameters**
#
# - **Learning Rate**:controls the step size at each iteration for Lower values
#
# - **n_estimators-Number of trees**: controls the number of boosting rounds. More trees may lead to overfitting, so thsi finds the  optimal value.
#
# - **Maximum Depth**: specifies the maximum depth of a tree. Deeper trees can capture more complex relationships ( may lead to overfitting)
#
# - **Minimum Child Weight**: controls the minimum sum of instance weight needed, can be used to control over-fitting.
#
# Grid Search help to find the most optimal value

# %%
# Define the hyperparameters to tune and their possible values
from sklearn.model_selection import GridSearchCV

param_grid= {'learning_rate': [None,0.01, 0.1, 0.2],'n_estimators': [50,100, 200, 300],'max_depth': [None,3, 4, 5], 'min_child_weight': [None,1, 2, 3]}

# Create a GridSearchCV object
gs_xgb = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=3, scoring='f1')

# Fit the GridSearchCV to the data
gs_xgb.fit(X_train_sm, Y_train_sm)

# Print the best hyperparameters
print("Best Hyperparameters:")
print(gs_xgb.best_params_)
# Out:
# Best Hyperparameters:
# {'learning_rate': None, 'max_depth': None, 'min_child_weight': None, 'n_estimators': 50}

# %%
# Predicting the model
Y_xgb_hp = gs_xgb.predict(X_test)

# XGBoost model with the best hyperparameters
best_xgb_model = XGBClassifier(learning_rate=0.01, max_depth=4, n_estimators=100, min_child_weight=1)

# Train the model on the full training data
best_xgb_model.fit(X_train_sm, Y_train_sm)

# Predictions on the test data
Y_xgb_hp = best_xgb_model.predict(X_test)

# Model evaluation
accuracy = accuracy_score(Y_test, Y_xgb_hp)
print(f"Accuracy: {accuracy:.4f}")

classification_rep = classification_report(Y_test, Y_xgb_hp)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.9083
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        58
#            1       0.95      0.92      0.94       261
#            2       0.69      0.83      0.76        41
#
#     accuracy                           0.91       360
#    macro avg       0.85      0.88      0.86       360
# weighted avg       0.91      0.91      0.91       360

# %% [markdown]
# # 7. Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB

#instance of the Multinomial Naive Bayes model
nb = BernoulliNB()

# Fit the model
nb.fit(X_train_sm, Y_train_sm)
# Out:
# BernoulliNB()

# %%
# Predicting the model
Y_prednb = nb.predict(X_test)
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(Y_test,Y_prednb))
print(classification_report(Y_test,Y_prednb))
print(confusion_matrix(Y_test, Y_prednb))
# Out:
# 0.4777777777777778
#               precision    recall  f1-score   support
#
#            0       0.36      0.76      0.49        58
#            1       0.78      0.44      0.56       261
#            2       0.14      0.32      0.20        41
#
#     accuracy                           0.48       360
#    macro avg       0.43      0.51      0.42       360
# weighted avg       0.64      0.48      0.51       360
#
# [[ 44  14   0]
#  [ 69 115  77]
#  [ 10  18  13]]

# %% [markdown]
# # DEEP LEARNING MODEL
# - Using The Multi-layer Perceptron (MLP) for the ANN Model, this feedforward neural network with multiple layers of nodes, including an input layer, more hidden layers, and an output layer will be used for this milticlass classification Task.

# %% [markdown]
# # 8. Artificial Neural Network

# %% [markdown]
# **Parameters**
#
# - **hidden_layer_sizes**:architecture of the neural network's hidden layers. in this ANN model there are three hidden layers, each with 100 neurons, the values represent the number of neurons in each hidden layer.
#
# - **activation Function**: logistic activationin function specifies the activation function to be used in the hidden layers it uses logistic sigmoid function and introduces non-linearity into the model. "relu" which is the most commonly used activation function was tried and tested but in terns of results, "logistic function" gave a better resuls.
#
# - **batch_size**: the number of samples used in each forward and backward pass during training, a value of 100 means that 100 samples will be used in each iteration to update the model's weights.
#
# - **learning_rate_init**: the initial learning rate for the optimization algorithm, it controls the step size during the training process. In this case, it's set to 0.01.
#
# - **max_iter**: determines the maximum number of iterations (epochs) the neural network will undergo during training. in this case Training will stop after 3000 iterations.
#
# - **random_state**: sets the seed for the random number generator, It helps make the training process reproducible.

# %%
# Training the model
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(100,100,100),activation='logistic',batch_size=100,learning_rate_init=0.01,max_iter=3000,random_state=10)
mlp.fit(X_train_sm,Y_train_sm)

default_params = mlp.get_params()

# Print the default parameters
print(default_params)
# Out:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 100, 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.01, 'max_fun': 15000, 'max_iter': 3000, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 10, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}

# %%
# Predicting the model
Y_predANN = mlp.predict(X_test)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(Y_test,Y_predANN))
print(classification_report(Y_test,Y_predANN))
print(confusion_matrix(Y_test, Y_predANN))
# Out:
# 0.8166666666666667
#               precision    recall  f1-score   support
#
#            0       0.82      0.72      0.77        58
#            1       0.86      0.90      0.88       261
#            2       0.49      0.41      0.45        41
#
#     accuracy                           0.82       360
#    macro avg       0.72      0.68      0.70       360
# weighted avg       0.81      0.82      0.81       360
#
# [[ 42  16   0]
#  [  8 235  18]
#  [  1  23  17]]

# %% [markdown]
# # Artificial Neural Network After Hyper-Parameter Tuning

# %%
# Define the hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50, 50, 50), (100, 100, 100), (100)],
    'activation': ['logistic', 'tanh', 'relu'],
    'batch_size': [10, 50, 100],
    'learning_rate': ['constant', 0.001, 0.01, 0.1],
    'random_state': [10, 20, 30],
    'max_iter': [300]
}

# Create an MLPClassifier
mlp = MLPClassifier()

# Create a GridSearchCV instance
ann_hp = GridSearchCV(mlp, param_grid, cv=10, n_jobs=-1, scoring='accuracy')

# %%
# Fit the grid search to your data
ann_hp.fit(X_train_sm, Y_train_sm)

# Get the best parameters and estimator
best_params = ann_hp.best_params_
best_estimator = ann_hp.best_estimator_

# Use the best estimator to make predictions
Y_ann_hp = best_estimator.predict(X_test)

# %%
default_params =ann_hp.get_params()

# Print the parameters of hyperparameter tuning (saving the values since iterations take long)
print(default_params)
# Out:
# {'cv': 10, 'error_score': nan, 'estimator__activation': 'relu', 'estimator__alpha': 0.0001, 'estimator__batch_size': 'auto', 'estimator__beta_1': 0.9, 'estimator__beta_2': 0.999, 'estimator__early_stopping': False, 'estimator__epsilon': 1e-08, 'estimator__hidden_layer_sizes': (100,), 'estimator__learning_rate': 'constant', 'estimator__learning_rate_init': 0.001, 'estimator__max_fun': 15000, 'estimator__max_iter': 200, 'estimator__momentum': 0.9, 'estimator__n_iter_no_change': 10, 'estimator__nesterovs_momentum': True, 'estimator__power_t': 0.5, 'estimator__random_state': None, 'estimator__shuffle': True, 'estimator__solver': 'adam', 'estimator__tol': 0.0001, 'estimator__validation_fraction': 0.1, 'estimator__verbose': False, 'estimator__warm_start': False, 'estimator': MLPClassifier(), 'n_jobs': -1, 'param_grid': {'hidden_layer_sizes': [(50, 50, 50), (100, 100, 100), 100], 'activation': ['logistic', 'tanh', 'relu'], 'batch_size': [10, 50, 100], 'learning_rate': ['constant', 0.001, 0.
# ...

# %%
# Evaluate the model
accuracy = accuracy_score(Y_test, Y_ann_hp)
print(f"Accuracy: {accuracy:.4f}")
print(confusion_matrix(Y_test, Y_ann_hp))
print(classification_report(Y_test,Y_ann_hp))
# Out:
# Accuracy: 0.8306
# [[ 39  19   0]
#  [  3 240  18]
#  [  1  20  20]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.67      0.77        58
#            1       0.86      0.92      0.89       261
#            2       0.53      0.49      0.51        41
#
#     accuracy                           0.83       360
#    macro avg       0.76      0.69      0.72       360
# weighted avg       0.83      0.83      0.83       360

# %% [markdown]
# # COMPARISON REPORT - Using Pretty Table

# %%
# from prettytable import PrettyTable
#calculated the evaluation scores for each model separately

from prettytable import PrettyTable
# Assuming you have already calculated the evaluation scores for each model
Random_Forest_Before_Tuning  = [0.93, (0.87,0.95,0.83),(0.83,0.96,0.83), (0.92,0.94,0.83)]
Random_Forest_After_Tuning   = [0.94, (0.91,0.96,0.84),(0.90,0.97,0.80), (0.93,0.95,0.87)]
XGBoost_Before_Tuning        = [0.90, (0.85,0.93,0.75),(0.81,0.93,0.78), (0.89,0.93,0.73)]
XGBoost_After_Tuning         = [0.91, (0.90,0.94,0.76),(0.90,0.92,0.83), (0.90,0.95,0.69)]
Decision_Tree_Before_Tuning  = [0.86, (0.79,0.91,0.70),(0.74,0.90,0.80), (0.84,0.92,0.62)]
Decision_Tree_After_Tuning   = [0.87, (0.82,0.91,0.69),(0.78,0.90,0.80), (0.87,0.92,0.60)]
Artificial_Neural_Network_Before_Tuning= [0.82, (0.77,0.88,0.45),(0.72,0.90,0.41), (0.82,0.86,0.49)]
Artificial_Neural_Network_After_Tuning = [0.83, (0.77,0.89,0.51),(0.67,0.92,0.49), (0.91,0.86,0.53)]
Support_Vector_before_tuning = [0.66, (0.53,0.75,0.51),(0.62,0.64,0.88), (0.46,0.92,0.36)]
Support_Vector_after_tuning  = [0.73, (0.44,0.83,0.45),(0.38,0.85,0.46), (0.52,0.81,0.43)]
Logistic_Regression          = [0.72, (0.60,0.81,0.48),(0.67,0.73,0.71), (0.55,0.91,0.36)]
K_Nearest_Neighbour          = [0.51,  (0.37,0.60,0.43),(0.64,0.46,0.61), (0.26,0.85,0.34)]
Naive_Bayes                  = [0.48,  (0.49,0.56,0.20),(0.76,0.44,0.32), (0.36,0.78,0.14)]


# Create a PrettyTable instance and add columns
table = PrettyTable()
table.field_names = ["Model", "Accuracy", "F1-Score", "Recall", "Precision"]
# Add rows for each model
table.add_row(["*Random Forest (Before_Tuning)",*Random_Forest_Before_Tuning]) 
table.add_row(["*Random Forest (After_Tuning)",*Random_Forest_After_Tuning]) 
table.add_row(["*XGBoost (Before_Tuning)",*XGBoost_Before_Tuning])      
table.add_row(["*XGBoost (After_Tuning)",*XGBoost_After_Tuning]) 
table.add_row(["*Decision Tree (Before Tuning)",*Decision_Tree_Before_Tuning])
table.add_row(["*Decision_Tree (After_Tuning)",*Decision_Tree_After_Tuning])
table.add_row(["*Artificial Neural Network (Before Tuning)",*Artificial_Neural_Network_Before_Tuning])
table.add_row(["*Artificial Neural Network (After Tuning)",*Artificial_Neural_Network_Before_Tuning])
table.add_row(["Support Vector Classifier",* Support_Vector_before_tuning])
table.add_row(["Support Vector Classifier after tuning",* Support_Vector_after_tuning])
table.add_row(["Logistic Regression",*Logistic_Regression])
table.add_row(["K-NearestNeighbour",*K_Nearest_Neighbour])               
table.add_row(["Naive Bayes",*Naive_Bayes])                  
print(table)
# Out:
# +--------------------------------------------+----------+--------------------+--------------------+--------------------+
# |                   Model                    | Accuracy |      F1-Score      |       Recall       |     Precision      |
# +--------------------------------------------+----------+--------------------+--------------------+--------------------+
# |       *Random Forest (Before_Tuning)       |   0.93   | (0.87, 0.95, 0.83) | (0.83, 0.96, 0.83) | (0.92, 0.94, 0.83) |
# |       *Random Forest (After_Tuning)        |   0.94   | (0.91, 0.96, 0.84) |  (0.9, 0.97, 0.8)  | (0.93, 0.95, 0.87) |
# |          *XGBoost (Before_Tuning)          |   0.9    | (0.85, 0.93, 0.75) | (0.81, 0.93, 0.78) | (0.89, 0.93, 0.73) |
# |          *XGBoost (After_Tuning)           |   0.91   | (0.9, 0.94, 0.76)  | (0.9, 0.92, 0.83)  | (0.9, 0.95, 0.69)  |
# |       *Decision Tree (Before Tuning)       |   0.86   | (0.79, 0.91, 0.7)  |  (0.74, 0.9, 0.8)  | (0.84, 0.92, 0.62) |
# ...

# %% [markdown]
# Note:  The 3 Values under each evaluation matrix of F1-Score, Recall and Precision represent each Prerformance Rating **'2,3,4'**( 1  excluded, as No employees performance is reated 'low') this rating scale was re-labled as '0,1,2' respectively and represent 'Good, Excellent, Outstanding' Respectively

# %% [markdown]
# # Task 3. To prepare a trained model which can predict the employee performance based on factors as inputs. This will be used to hire employees
#
# - The above prettyTable helps in comparing the Evaluation scores of each model.
# - The list of all the Models on the basis of their Evaluation Metrics  performance (High to Low)
# - Scores of F1 Score, Recall, Precision are in Weighted Average form below:
#
# 1. **Random Forest Model**: Has an accuracy score of:**0.936**, F1 Score:**94**, Recall:**94**, Precision:**0.94** there is the best model for this Project. Followed by,
#
# 2. **XGBoost Model**:  Has an accuracy score of:**0.91**, F1 Score:**0.91**, Recall:**0.91**, Precision:**0.91**, therefore the second best model. Followed by,
#
# 3. **Decision Tree Model**:Has an accuracy score of:**0.87**, F1 Score:**87**, Recall:**87**, Precision:**0.88**, followed by,
#
# 4. **Artificial Neural Network**: This model has an accuracy score of:**0.83**, F1 Score:**83**, Recall:**83**, Precision:**0.83**. Followed by,
#
# 5. **Support Vector Classifier**: Has an accuracy score of:**0.73**, F1 Score:**72**, Recall:**73**, Precision:**0.72**, making it one of the average performing Models along with; logistic regression.
#
# 6. **Logistic Regression Model**: Has an accuracy score of:**0.72**, F1 Score:**74**, Recall:**72**, Precision:**0.79**, followed by the lowest performing models;
#
# 7. **K-NearestNeighbour Classifier**: Has an accuracy score of:**0.51**, F1 Score:**54**, Recall:**51**, Precision:**0.71**, low enough to not make accurate predictions. followed by,
#
# 8. **Naive Bayes Model**: It an accuracy score of:**0.48**, F1 Score:**51**, Recall:**48**, Precision:**0.64**, making it unfit to make predictions for this data.
#
# #### Conclusion on Task 3:
#
# - From the above explaination and Pretty Table it can be concluded that the best performing model for this Data set is Random Forest, XGBoost, Decision Tree and Artificial Neural Network Model (respectively). These Models can Best predict the employee performance based inputs, and  to hire employees at INX Future Inc.

# %% [markdown]
# ### Task 4. Recommendations to improve the employee performance based on insights from analysis
#
#
# **1. Indicators of non performing employees and Corrective measures INX can make**
# - Departments such as The Research and Development and sales department have the highest **overtime** work percentage these departments can have flixible work hours or work from home options or work with incentives. **The Last salary hike Percentage** playes a major role in the employee Performance Rating. As a recognition for their hard work such incentives can be given.
# - Employees from Departments such as Finance and Sales have a large percentage of Performance Rating '2' which is the lowest so far. these departments can be encouraged with similar incentives as it has a positive impact on Employee Performance.
# - the managemnet can ensure that their employees have a good manager managing them preferably one with a a lot of experiance as it is observed that the **current manager** can have a huge influence on the **Environment Satisfaction** of an employee and the environment Satisfaction inturn is a major component that effects the Performance rating of an employee.
#
#
#
#
# **2.** As per the management, there has been a noticeable increase in service delivery and Client satisfaction levels have come down by 8 percentage points**
# -  More employees can be recruited as the work load increases and employees have to face overtime specially in the Research and Development and sales Department, this would also lead to an improved  **Work Life Balance** of employees which is also affected in this process.
# - Youthful Employees of the Age 18-20 and senior most employees with expertise and experiance can be hired further on as they display higher performance. In contrary those Age groups in between with lower ratings can be given Training, Feedbacks, Replanishment activities/breaks after a heavy work load. when the employees serve with knowledge and expertise the customers satisfaction levels will rise.
#
#
#
#
# **3.** Insted of direct **Penalization of non-performing employees** above mentioned reccomendations can come in handy as they will have minimal/No impact on the morale of other employees
# - as the last resort, Non Performing Employees can be Terminated. this will have a low or negligible impact on other employees as the correlation coefficient between Attrition and Performance Rating is 0.039 (4%) this is an extremely low rate, this explains that the Attrition does not have a significant impact on Performance.

# %% [markdown]
# *Submission Date 23-0ctober-2023*
